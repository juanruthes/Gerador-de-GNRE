# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
notafiscal = pd.read_excel(
        r'C:\Users\juan.santos\Desktop\Gerador de GNRE\data\Nota_Fiscal.xlsx')

notafiscal
# Out:
# c:\Users\juan.santos\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    Import Status  Import Code  Import Message  Companhia  \
# 0            NaN          NaN             NaN        460
# 1            NaN          NaN             NaN        460
# 2            NaN          NaN             NaN        460
# 3            NaN          NaN             NaN        460
# 4            NaN          NaN             NaN        460
# 5            NaN          NaN             NaN        460
# 6            NaN          NaN             NaN        460
#
#   Nota fiscal eletrônica     Data de emissão       Data de saída  Serie  \
# 0                    Sim 2024-05-20 09:39:37 2024-05-20 09:39:37      2
# 1                    Sim 2024-05-20 09:39:38 2024-05-20 09:39:38      2
# 2                    Sim 2024-05-20 09:39:39 2024-05-20 09:39:39      2
# 3                    Sim 2024-05-20 09:39:41 2024-05-20 09:39:41      2
# 4                    Sim 2024-05-20 09:39:42 2024-05-20 09:39:42      2
# 5                    Sim 2024-05-20 09:39:43 2024-05-20 09:39:43      2
# 6                    Sim 2024-05-20 09:39:44 2024-05-20 09:39:44      2
#
#    Número do documento  Numero NFSe  ...  Cond. de entrega Consumidor final  \
# 0                86235          NaN  ...               CIF              Sim
# 1                86236          NaN  ...               FOB              Sim
# 2                86237          NaN  ...               FOB              Sim
# 3                86238          NaN  ...               FCA              Sim
# 4                86239          NaN  ...               FOB              Sim
# 5                86240          NaN  ...               FOB              Sim
# 6                86241          NaN  ...               FOB              Sim
#
#                                     Localizador  Cond de pag Transportadora  \
# 0  41240576881093000172550020000862351000922264          867            A10
# 1  41240576881093000172550020000862361000922270          307            017
# 2  41240576881093000172550020000862371000922285            0            017
# 3  41240576881093000172550020000862381000922290          128            295
# 4  41240576881093000172550020000862391000922301          128            017
# 5  41240576881093000172550020000862401000922310          128            017
# 6  41240576881093000172550020000862411000922326          128            017
#
#                       Unnamed: 32 Endereço para faturamento PN receptor  \
# 0  ABS - LOG TRANSPORTE ORG LOG E                 BR0024608   BR0025553
# 1      TRANSJOI TRANSPORTES LTDA.                 BR0005526   BR1901105
# 2      TRANSJOI TRANSPORTES LTDA.                 BR0004403   BR1520826
# 3       ACEVILLE TRANSPORTES LTDA                 BR0025285   BR0026229
# 4      TRANSJOI TRANSPORTES LTDA.                 BR0001358   BR1020159
# 5      TRANSJOI TRANSPORTES LTDA.                 BR0001509   BR1021878
# 6      TRANSJOI TRANSPORTES LTDA.                 BR0014114   BR0015419
#
#    Código do tipo de doc. fiscal  Departamento
# 0                         S116FA        BR0101
# 1                           S101        BR0101
# 2                         S101CF        BR0101
# 3                           S101        BR0101
# 4                         S101CF        BR0101
# 5                           S101        BR0101
# 6                           S101        BR0101
#
# [7 rows x 37 columns]

# %%
for col in notafiscal:
    print(col)
# Out:
# ['Import Status',
#  'Import Code',
#  'Import Message',
#  'Companhia',
#  'Nota fiscal eletrônica',
#  'Data de emissão',
#  'Data de saída',
#  'Serie',
#  'Número do documento',
#  'Numero NFSe',
#  'Referência fiscal',
#  'Parceiro de negócios faturado',
#  'Unnamed: 12',
#  'CFO',
#  'Status da fatura',
#  'Status da NF-e',
#  'Status transmissão',
#  'NF manual',
#  'Valor total',
#  'Valor total da agenda',
#  'Unnamed: 20',
#  'Tipo doc. fiscal',
#  'Protocolo NF-e',
#  'Código da razão cancelamento',
#  'Req.faturamento',
#  'Modalidade do Frete',
#  'Terceiros 2 NF',
#  'Cond. de entrega',
#  'Consumidor final',
#  'Localizador',
#  'Cond de pag',
#  'Transportadora',
#  'Unnamed: 32',
#  'Endereço para faturamento',
#  'PN receptor',
#  'Código do tipo de doc. fiscal',
#  'Departamento']
